# %% [markdown]
# # Luderick Object Detection Using YOLOv5 (Inference)

# %% [markdown]
# ## Load the preprocessed DataFrames generated in the preprocessing Notebook

# %%
# all imports
import pandas as pd
import numpy as np
import torch
import ast
import cv2
import matplotlib.pyplot as plt
import time
from PIL import Image
import os

plt.style.use('ggplot')

# %%
# Constants
MODELS_DIR = 'models'
IMAGES_DIR = 'Fish_automated_identification_and_counting/luderick-seagrass'
VIDEOS_DIR = 'Fish_automated_identification_and_counting/videos'
CLASSES = ['luderick']
NUM_CLASSES = len(CLASSES)
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
INFERENCE_OUTPUT_DIR = 'inference_outputs'
# !mkdir {INFERENCE_OUTPUT_DIR}
# Out:
# Ya existe el subdirectorio o el archivo inference_outputs.

# %%
def load_luderick_df(file_path):
    """
    Loads a preprocessed luderick dataframe from a .csv and converts its 
    array column from string to a proper array
    """
    loaded_df = pd.read_csv(file_path)
    loaded_df['labels'] = loaded_df['labels'].apply(lambda x: ast.literal_eval(x))
    loaded_df['bounding_boxes'] = loaded_df['bounding_boxes'].apply(lambda x: ast.literal_eval(x))
    loaded_df['area'] = loaded_df['area'].apply(lambda x: ast.literal_eval(x))
    loaded_df['segmentation'] = loaded_df['segmentation'].apply(lambda x: ast.literal_eval(x))
    
    return loaded_df

# %%
validation_df = load_luderick_df('luderick_validation_preprocessed.csv')
test_df = load_luderick_df('luderick_test_preprocessed.csv')

validation_df
# Out:
#                              image_name        video_name  frame_number  \
# 0           04C2_Luderick_16_000400.jpg  04C2_Luderick_16             1
# 1           04C2_Luderick_16_000600.jpg  04C2_Luderick_16             2
# 2           04C2_Luderick_16_000800.jpg  04C2_Luderick_16             3
# 3           04C2_Luderick_16_001000.jpg  04C2_Luderick_16             4
# 4           04C2_Luderick_16_001200.jpg  04C2_Luderick_16             5
# ..                                  ...               ...           ...
# 819  C1_Luderick_14.mov_5fps_000013.jpg    C1_Luderick_14            13
# 820  C1_Luderick_14.mov_5fps_000014.jpg    C1_Luderick_14            14
# 821  C1_Luderick_14.mov_5fps_000015.jpg    C1_Luderick_14            15
# 822  C1_Luderick_14.mov_5fps_000016.jpg    C1_Luderick_14            16
# 823            brim.mov_5fps_000002.jpg              brim             1
#
#      number_boxes        labels  \
# 0               1           [1]
# 1               1           [1]
# 2               1           [1]
# 3               1           [1]
# 4               1           [1]
# ..            ...           ...
# 819             3     [1, 1, 1]
# 820             3     [1, 1, 1]
# 821             4  [1, 1, 1, 1]
# 822             3     [1, 1, 1]
# 823             1           [1]
#
#                                         bounding_boxes  \
# 0                                 [[2, 581, 163, 755]]
# 1                                 [[2, 586, 223, 765]]
# 2                                 [[0, 589, 281, 760]]
# 3                                 [[2, 588, 339, 748]]
# 4                                 [[2, 580, 380, 746]]
# ..                                                 ...
# 819  [[414, 235, 701, 432], [1584, 449, 1868, 590],...
# 820  [[320, 254, 573, 449], [1457, 310, 1714, 451],...
# 821  [[1455, 476, 1737, 611], [1397, 304, 1697, 444...
# 822  [[214, 314, 372, 504], [1325, 303, 1703, 442],...
# 823                             [[329, 565, 432, 663]]
#
#                              area  \
# 0                         [28014]
# 1                         [39559]
# 2                         [48051]
# 3                         [53920]
# 4                         [62748]
# ..                            ...
# 819         [56539, 40044, 24924]
# 820         [49335, 36237, 42000]
# 821  [38070, 42000, 12314, 40425]
# 822         [30020, 52542, 38676]
# 823                       [10094]
#
#                                           segmentation
# 0    [[163, 703, 146, 678, 125, 649, 93, 620, 58, 6...
# 1    [[223, 711, 218, 728, 195, 731, 131, 746, 107,...
# 2    [[281, 703, 279, 722, 237, 732, 165, 751, 98, ...
# 3    [[339, 700, 307, 711, 276, 726, 232, 737, 220,...
# 4    [[380, 678, 354, 646, 308, 607, 253, 581, 200,...
# ..                                                 ...
# 819  [[701, 235, 699, 250, 699, 273, 692, 310, 690,...
# 820  [[573, 254, 573, 271, 566, 314, 560, 335, 556,...
# 821  [[1716, 476, 1716, 504, 1722, 526, 1737, 570, ...
# 822  [[372, 314, 370, 327, 365, 344, 355, 372, 331,...
# 823  [[432, 628, 432, 622, 426, 584, 422, 579, 414,...
#
# [824 rows x 8 columns]

# %% [markdown]
# ## Load YOLOv5 Model

# %% [markdown]
# ### YOLOv5s small size model

# %%
model_path = f"{MODELS_DIR}/best_YOLOv5s_model_1.pt" 
model_s = torch.hub.load('ultralytics/yolov5', 'custom', path=model_path)  # local model
model_s.to(DEVICE).eval();
# Out:
# Using cache found in C:\Users\Ricard/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-5-8 torch 1.11.0 CUDA:0 (NVIDIA GeForce GTX 970, 4096MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ### YOLOv5m medium size model

# %%
model_path = f"{MODELS_DIR}/best_YOLOv5m_model_1.pt" 
model_m = torch.hub.load('ultralytics/yolov5', 'custom', path=model_path)  # local model
model_m.to(DEVICE).eval();
# Out:
# Using cache found in C:\Users\Ricard/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-5-8 torch 1.11.0 CUDA:0 (NVIDIA GeForce GTX 970, 4096MiB)
#
# Fusing layers...
# Model summary: 290 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ### YOLOv5l large size model

# %%
model_path = f"{MODELS_DIR}/best_YOLOv5l_model_1.pt" 
model_l = torch.hub.load('ultralytics/yolov5', 'custom', path=model_path)  # local model
model_l.to(DEVICE).eval();
# Out:
# Using cache found in C:\Users\Ricard/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-5-8 torch 1.11.0 CUDA:0 (NVIDIA GeForce GTX 970, 4096MiB)
#
# Fusing layers...
# Model summary: 367 layers, 46108278 parameters, 0 gradients, 107.8 GFLOPs
# Adding AutoShape...

# %%
# Visualize the model's prediction format
image = Image.open(f"{IMAGES_DIR}/C1_Luderick_14.mov_5fps_000013.jpg")
results = model_m(image)
results.print()
results.pandas().xyxy[0]
# Out:
# image 1/1: 1080x1920 3 ludericks
# Speed: 31.0ms pre-process, 27.0ms inference, 6.0ms NMS per image at shape (1, 3, 384, 640)
#           xmin        ymin         xmax        ymax  confidence  class  \
# 0   397.627563  236.689697   697.171753  437.110107    0.943445      0
# 1  1582.460205  437.462463  1865.663574  587.593262    0.927670      0
# 2  1516.050781  318.521057  1729.309570  451.021301    0.904255      0
#
#        name
# 0  luderick
# 1  luderick
# 2  luderick

# %% [markdown]
#  ## Predict Function

# %%
def predict(image, model):
    """
    Return, as arrays, the detection bounding boxes, labels, pred_scores and inference time in an PIL Image (RGB) using a 
    given model above a given detection_threshold.
    """ 
    start_time = time.time()
    with torch.no_grad():
        results = model(image) # get the predictions on the image
    end_time = time.time()
    inference_time = end_time - start_time
    
    # get the results as a pandas dataframe
    results_pandas = results.pandas().xyxy[0]
    
    return results_pandas, inference_time

# %% [markdown]
# ## Function to Draw Bounding Boxes Around an Object
#
# A bounding box has a format of [x_min, y_min, x_max, y_max]

# %%
def draw_boxes(results_df, image, color=(255, 0, 0)):
    """
    Returns an image array that contains the predicted bounding boxes, labels and scores
    """
    # read the image with OpenCV
    image = np.asarray(image)
    for index, row in results_df.iterrows():
        box = [row['xmin'], row['ymin'], row['xmax'], row['ymax']]
        cv2.rectangle(image,
                     (int(box[0]), int(box[1])), (int(box[2]), int(box[3])),
                     color, 2)
        bbox_text = f"{row['name']} {str(round(row['confidence']*100, 2))}" # showing probability scores
        cv2.putText(image, bbox_text, (int(box[0]), int(box[1] - 5)),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2,
                   lineType=cv2.LINE_AA)
    
    return image

# %%
def view_image(image_array):
    """
    Display the image array
    """
    image = Image.fromarray((image_array).astype(np.uint8))  # Pil Image needs the image to be in int format
    display(image)

# %%
# visualize predicted bounding boxes from one image from the validation dataset

# Some PIL Images converted to arrays have 4 color channel unless .convert('RGB') is used
image = Image.open(f"{IMAGES_DIR}/C1_Luderick_14.mov_5fps_000013.jpg").convert('RGB') 
# set detection threshold
model_m.conf = 0.8
# predict results
results_df, inf_time = predict(image, model_m)
image_boxes = draw_boxes(results_df, image)
print(f'Inference time = {inf_time} seconds')
view_image(image_boxes)
torch.cuda.empty_cache()
# Out:
# Inference time = 0.0379946231842041 seconds
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x22E8F1DDA48>

# %% [markdown]
# ## Inference on the full dataset

# %%
def predict_whole_dataset(luderick_df, model, images_dir, output_dir, score_threshold=0.8):
    """
    Carry out object detection on all the images from a preprocessed luderick dataset
    and save them with bounding boxes, labels and prediction scores printed at the desired folder
    """
    image_names = luderick_df['image_name'].values
    total_fps = 0
    frame_count = 0
    # set model confidence score threshold
    model.conf = score_threshold
    
    for i, image_name in enumerate(image_names):
            # load the image
            image = Image.open(f"{images_dir}/{image_name}").convert('RGB') 
            # use the model to get the predictions
            results_df, inf_time = predict(image, model)
            # draw the image boxes
            image_boxes = draw_boxes(results_df, image)
            # get the current fps
            fps = 1 / inf_time
            # increase total fps
            total_fps += fps
            # increment frame count
            frame_count += 1
            image_boxes = cv2.cvtColor(image_boxes, cv2.COLOR_BGR2RGB).astype(np.float32)
            cv2.imwrite(f"{output_dir}/{image_name}", image_boxes)
            print(f"Detection on image {i+1} finished...")
            print('-'*50)
    
    print('Dataset detection completed.')
    # calculate and print the average FPS
    avg_fps = total_fps / frame_count
    print(f"Average FPS: {avg_fps:.3f}")

# %% [markdown]
# ### YOLOV5m medium model

# %%
folder_name = 'validation_images_YOLOv5m_model_1'
# %cd {INFERENCE_OUTPUT_DIR}
# !mkdir {folder_name}
# %cd ..

output_dir = f"{INFERENCE_OUTPUT_DIR}/{folder_name}"
predict_whole_dataset(validation_df, model_m, IMAGES_DIR, output_dir, 0.8)
torch.cuda.empty_cache()
# Out:
# C:\Users\Ricard\Desktop\Master\TFM\notebooks\Luderick_Seagrass\inference_outputs
# C:\Users\Ricard\Desktop\Master\TFM\notebooks\Luderick_Seagrass
# Ya existe el subdirectorio o el archivo validation_images_YOLOv5m_model_1.
# Detection on image 1 finished...
# --------------------------------------------------
# Detection on image 2 finished...
# --------------------------------------------------
# Detection on image 3 finished...
# --------------------------------------------------
# Detection on image 4 finished...
# --------------------------------------------------
# Detection on image 5 finished...
# --------------------------------------------------
# Detection on image 6 finished...
# --------------------------------------------------
# Detection on image 7 finished...
# --------------------------------------------------
# Detection on image 8 finished...
# --------------------------------------------------
# Detection on image 9 finished...
# --------------------------------------------------
# Detection on image 10 finished...
# --------------------------------------------------
# Detection on image 11 finished...
# --------------------------------------------------
# Detection on image 12 finished...
# --------------------------------------------------
# Detection on image 13 finished...
# --------------------------------------------------
# Detection on image 14 finished...
# --------------------------------------------------
# Detection on image 15 finished...
# --------------------------------------------------
# Detection on image 16 finished...
# --------------------------------------------------
# Detection on image 17 finished...
# --------------------------------------------------
# Detection on image 18 finished...
# --------------------------------------------------
# Detection on image 19 finished...
# --------------------------------------------------
# Detection on image 20 finished...
# --------------------------------------------------
# Detection on image 21 finished...
# --------------------------------------------------
# Detection on image 22 finished...
# --------------------------------------------------
# Detection on image 23 finished...
# --------------------------------------------------
# Detection on image 24 finished...
# --------------------------------------------------
# Detection on image 25 finished...
# --------------------------------------------------
# Detection on image 26 finished...
# --------------------------------------------------
# Detection on image 27 finished...
# --------------------------------------------------
# Detection on image 28 finished...
# --------------------------------------------------
# Detection on image 29 finished...
# --------------------------------------------------
# Detection on image 30 finished...
# --------------------------------------------------
# Detection on image 31 finished...
# --------------------------------------------------
# Detection on image 32 finished...
# --------------------------------------------------
# Detection on image 33 finished...
# --------------------------------------------------
# Detection on image 34 finished...
# --------------------------------------------------
# Detection on image 35 finished...
# --------------------------------------------------
# Detection on image 36 finished...
# --------------------------------------------------
# Detection on image 37 finished...
# --------------------------------------------------
# Detection on image 38 finished...
# --------------------------------------------------
# Detection on image 39 finished...
# --------------------------------------------------
# Detection on image 40 finished...
# --------------------------------------------------
# Detection on image 41 finished...
# --------------------------------------------------
# Detection on image 42 finished...
# --------------------------------------------------
# Detection on image 43 finished...
# --------------------------------------------------
# Detection on image 44 finished...
# --------------------------------------------------
# Detection on image 45 finished...
# --------------------------------------------------
# Detection on image 46 finished...
# --------------------------------------------------
# Detection on image 47 finished...
# --------------------------------------------------
# Detection on image 48 finished...
# --------------------------------------------------
# Detection on image 49 finished...
# --------------------------------------------------
# Detection on image 50 finished...
# --------------------------------------------------
# Detection on image 51 finished...
# --------------------------------------------------
# Detection on image 52 finished...
# --------------------------------------------------
# Detection on image 53 finished...
# --------------------------------------------------
# Detection on image 54 finished...
# --------------------------------------------------
# Detection on image 55 finished...
# --------------------------------------------------
# Detection on image 56 finished...
# --------------------------------------------------
# Detection on image 57 finished...
# --------------------------------------------------
# Detection on image 58 finished...
# --------------------------------------------------
# Detection on image 59 finished...
# --------------------------------------------------
# Detection on image 60 finished...
# --------------------------------------------------
# Detection on image 61 finished...
# --------------------------------------------------
# Detection on image 62 finished...
# --------------------------------------------------
# Detection on image 63 finished...
# --------------------------------------------------
# Detection on image 64 finished...
# --------------------------------------------------
# Detection on image 65 finished...
# --------------------------------------------------
# Detection on image 66 finished...
# --------------------------------------------------
# Detection on image 67 finished...
# --------------------------------------------------
# Detection on image 68 finished...
# --------------------------------------------------
# Detection on image 69 finished...
# --------------------------------------------------
# Detection on image 70 finished...
# --------------------------------------------------
# Detection on image 71 finished...
# --------------------------------------------------
# Detection on image 72 finished...
# --------------------------------------------------
# Detection on image 73 finished...
# --------------------------------------------------
# Detection on image 74 finished...
# --------------------------------------------------
# Detection on image 75 finished...
# --------------------------------------------------
# Detection on image 76 finished...
# --------------------------------------------------
# Detection on image 77 finished...
# --------------------------------------------------
# Detection on image 78 finished...
# --------------------------------------------------
# Detection on image 79 finished...
# --------------------------------------------------
# Detection on image 80 finished...
# --------------------------------------------------
# Detection on image 81 finished...
# --------------------------------------------------
# Detection on image 82 finished...
# --------------------------------------------------
# Detection on image 83 finished...
# --------------------------------------------------
# Detection on image 84 finished...
# --------------------------------------------------
# Detection on image 85 finished...
# --------------------------------------------------
# Detection on image 86 finished...
# --------------------------------------------------
# Detection on image 87 finished...
# --------------------------------------------------
# Detection on image 88 finished...
# --------------------------------------------------
# Detection on image 89 finished...
# --------------------------------------------------
# Detection on image 90 finished...
# --------------------------------------------------
# Detection on image 91 finished...
# --------------------------------------------------
# Detection on image 92 finished...
# --------------------------------------------------
# Detection on image 93 finished...
# --------------------------------------------------
# Detection on image 94 finished...
# --------------------------------------------------
# Detection on image 95 finished...
# --------------------------------------------------
# Detection on image 96 finished...
# --------------------------------------------------
# Detection on image 97 finished...
# --------------------------------------------------
# Detection on image 98 finished...
# --------------------------------------------------
# Detection on image 99 finished...
# --------------------------------------------------
# Detection on image 100 finished...
# --------------------------------------------------
# Detection on image 101 finished...
# --------------------------------------------------
# Detection on image 102 finished...
# --------------------------------------------------
# Detection on image 103 finished...
# --------------------------------------------------
# Detection on image 104 finished...
# --------------------------------------------------
# Detection on image 105 finished...
# --------------------------------------------------
# Detection on image 106 finished...
# --------------------------------------------------
# Detection on image 107 finished...
# --------------------------------------------------
# Detection on image 108 finished...
# --------------------------------------------------
# Detection on image 109 finished...
# --------------------------------------------------
# Detection on image 110 finished...
# --------------------------------------------------
# Detection on image 111 finished...
# --------------------------------------------------
# Detection on image 112 finished...
# --------------------------------------------------
# Detection on image 113 finished...
# --------------------------------------------------
# Detection on image 114 finished...
# --------------------------------------------------
# Detection on image 115 finished...
# --------------------------------------------------
# Detection on image 116 finished...
# --------------------------------------------------
# Detection on image 117 finished...
# --------------------------------------------------
# Detection on image 118 finished...
# --------------------------------------------------
# Detection on image 119 finished...
# --------------------------------------------------
# Detection on image 120 finished...
# --------------------------------------------------
# Detection on image 121 finished...
# --------------------------------------------------
# Detection on image 122 finished...
# --------------------------------------------------
# Detection on image 123 finished...
# --------------------------------------------------
# Detection on image 124 finished...
# --------------------------------------------------
# Detection on image 125 finished...
# --------------------------------------------------
# Detection on image 126 finished...
# --------------------------------------------------
# Detection on image 127 finished...
# --------------------------------------------------
# Detection on image 128 finished...
# --------------------------------------------------
# Detection on image 129 finished...
# --------------------------------------------------
# Detection on image 130 finished...
# --------------------------------------------------
# Detection on image 131 finished...
# --------------------------------------------------
# Detection on image 132 finished...
# --------------------------------------------------
# Detection on image 133 finished...
# --------------------------------------------------
# Detection on image 134 finished...
# --------------------------------------------------
# Detection on image 135 finished...
# --------------------------------------------------
# Detection on image 136 finished...
# --------------------------------------------------
# Detection on image 137 finished...
# --------------------------------------------------
# Detection on image 138 finished...
# --------------------------------------------------
# Detection on image 139 finished...
# --------------------------------------------------
# Detection on image 140 finished...
# --------------------------------------------------
# Detection on image 141 finished...
# --------------------------------------------------
# Detection on image 142 finished...
# --------------------------------------------------
# Detection on image 143 finished...
# --------------------------------------------------
# Detection on image 144 finished...
# --------------------------------------------------
# Detection on image 145 finished...
# --------------------------------------------------
# Detection on image 146 finished...
# --------------------------------------------------
# Detection on image 147 finished...
# --------------------------------------------------
# Detection on image 148 finished...
# --------------------------------------------------
# Detection on image 149 finished...
# --------------------------------------------------
# Detection on image 150 finished...
# --------------------------------------------------
# Detection on image 151 finished...
# --------------------------------------------------
# Detection on image 152 finished...
# --------------------------------------------------
# Detection on image 153 finished...
# --------------------------------------------------
# Detection on image 154 finished...
# --------------------------------------------------
# Detection on image 155 finished...
# --------------------------------------------------
# Detection on image 156 finished...
# --------------------------------------------------
# Detection on image 157 finished...
# --------------------------------------------------
# Detection on image 158 finished...
# --------------------------------------------------
# Detection on image 159 finished...
# --------------------------------------------------
# Detection on image 160 finished...
# --------------------------------------------------
# Detection on image 161 finished...
# --------------------------------------------------
# Detection on image 162 finished...
# --------------------------------------------------
# Detection on image 163 finished...
# --------------------------------------------------
# Detection on image 164 finished...
# --------------------------------------------------
# Detection on image 165 finished...
# --------------------------------------------------
# Detection on image 166 finished...
# --------------------------------------------------
# Detection on image 167 finished...
# --------------------------------------------------
# Detection on image 168 finished...
# --------------------------------------------------
# Detection on image 169 finished...
# --------------------------------------------------
# Detection on image 170 finished...
# --------------------------------------------------
# Detection on image 171 finished...
# --------------------------------------------------
# Detection on image 172 finished...
# --------------------------------------------------
# Detection on image 173 finished...
# --------------------------------------------------
# Detection on image 174 finished...
# --------------------------------------------------
# Detection on image 175 finished...
# --------------------------------------------------
# Detection on image 176 finished...
# --------------------------------------------------
# Detection on image 177 finished...
# --------------------------------------------------
# Detection on image 178 finished...
# --------------------------------------------------
# Detection on image 179 finished...
# --------------------------------------------------
# Detection on image 180 finished...
# --------------------------------------------------
# Detection on image 181 finished...
# --------------------------------------------------
# Detection on image 182 finished...
# --------------------------------------------------
# Detection on image 183 finished...
# --------------------------------------------------
# Detection on image 184 finished...
# --------------------------------------------------
# Detection on image 185 finished...
# --------------------------------------------------
# Detection on image 186 finished...
# --------------------------------------------------
# Detection on image 187 finished...
# --------------------------------------------------
# Detection on image 188 finished...
# --------------------------------------------------
# Detection on image 189 finished...
# --------------------------------------------------
# Detection on image 190 finished...
# --------------------------------------------------
# Detection on image 191 finished...
# --------------------------------------------------
# Detection on image 192 finished...
# --------------------------------------------------
# Detection on image 193 finished...
# --------------------------------------------------
# Detection on image 194 finished...
# --------------------------------------------------
# Detection on image 195 finished...
# --------------------------------------------------
# Detection on image 196 finished...
# --------------------------------------------------
# Detection on image 197 finished...
# --------------------------------------------------
# Detection on image 198 finished...
# --------------------------------------------------
# Detection on image 199 finished...
# --------------------------------------------------
# Detection on image 200 finished...
# --------------------------------------------------
# Detection on image 201 finished...
# --------------------------------------------------
# Detection on image 202 finished...
# --------------------------------------------------
# Detection on image 203 finished...
# --------------------------------------------------
# Detection on image 204 finished...
# --------------------------------------------------
# Detection on image 205 finished...
# --------------------------------------------------
# Detection on image 206 finished...
# --------------------------------------------------
# Detection on image 207 finished...
# --------------------------------------------------
# Detection on image 208 finished...
# --------------------------------------------------
# Detection on image 209 finished...
# --------------------------------------------------
# Detection on image 210 finished...
# --------------------------------------------------
# Detection on image 211 finished...
# --------------------------------------------------
# Detection on image 212 finished...
# --------------------------------------------------
# Detection on image 213 finished...
# --------------------------------------------------
# Detection on image 214 finished...
# --------------------------------------------------
# Detection on image 215 finished...
# --------------------------------------------------
# Detection on image 216 finished...
# --------------------------------------------------
# Detection on image 217 finished...
# --------------------------------------------------
# Detection on image 218 finished...
# --------------------------------------------------
# Detection on image 219 finished...
# --------------------------------------------------
# Detection on image 220 finished...
# --------------------------------------------------
# Detection on image 221 finished...
# --------------------------------------------------
# Detection on image 222 finished...
# --------------------------------------------------
# Detection on image 223 finished...
# --------------------------------------------------
# Detection on image 224 finished...
# --------------------------------------------------
# Detection on image 225 finished...
# --------------------------------------------------
# Detection on image 226 finished...
# --------------------------------------------------
# Detection on image 227 finished...
# --------------------------------------------------
# Detection on image 228 finished...
# --------------------------------------------------
# Detection on image 229 finished...
# --------------------------------------------------
# Detection on image 230 finished...
# --------------------------------------------------
# Detection on image 231 finished...
# --------------------------------------------------
# Detection on image 232 finished...
# --------------------------------------------------
# Detection on image 233 finished...
# --------------------------------------------------
# Detection on image 234 finished...
# --------------------------------------------------
# Detection on image 235 finished...
# --------------------------------------------------
# Detection on image 236 finished...
# --------------------------------------------------
# Detection on image 237 finished...
# --------------------------------------------------
# Detection on image 238 finished...
# --------------------------------------------------
# Detection on image 239 finished...
# --------------------------------------------------
# Detection on image 240 finished...
# --------------------------------------------------
# Detection on image 241 finished...
# --------------------------------------------------
# Detection on image 242 finished...
# --------------------------------------------------
# Detection on image 243 finished...
# --------------------------------------------------
# Detection on image 244 finished...
# --------------------------------------------------
# Detection on image 245 finished...
# --------------------------------------------------
# Detection on image 246 finished...
# --------------------------------------------------
# Detection on image 247 finished...
# --------------------------------------------------
# Detection on image 248 finished...
# --------------------------------------------------
# Detection on image 249 finished...
# --------------------------------------------------
# Detection on image 250 finished...
# --------------------------------------------------
# Detection on image 251 finished...
# --------------------------------------------------
# Detection on image 252 finished...
# --------------------------------------------------
# Detection on image 253 finished...
# --------------------------------------------------
# Detection on image 254 finished...
# --------------------------------------------------
# Detection on image 255 finished...
# --------------------------------------------------
# Detection on image 256 finished...
# --------------------------------------------------
# Detection on image 257 finished...
# --------------------------------------------------
# Detection on image 258 finished...
# --------------------------------------------------
# Detection on image 259 finished...
# --------------------------------------------------
# Detection on image 260 finished...
# --------------------------------------------------
# Detection on image 261 finished...
# --------------------------------------------------
# Detection on image 262 finished...
# --------------------------------------------------
# Detection on image 263 finished...
# --------------------------------------------------
# Detection on image 264 finished...
# --------------------------------------------------
# Detection on image 265 finished...
# --------------------------------------------------
# Detection on image 266 finished...
# --------------------------------------------------
# Detection on image 267 finished...
# --------------------------------------------------
# Detection on image 268 finished...
# --------------------------------------------------
# Detection on image 269 finished...
# --------------------------------------------------
# Detection on image 270 finished...
# --------------------------------------------------
# Detection on image 271 finished...
# --------------------------------------------------
# Detection on image 272 finished...
# --------------------------------------------------
# Detection on image 273 finished...
# --------------------------------------------------
# Detection on image 274 finished...
# --------------------------------------------------
# Detection on image 275 finished...
# --------------------------------------------------
# Detection on image 276 finished...
# --------------------------------------------------
# Detection on image 277 finished...
# --------------------------------------------------
# Detection on image 278 finished...
# --------------------------------------------------
# Detection on image 279 finished...
# --------------------------------------------------
# Detection on image 280 finished...
# --------------------------------------------------
# Detection on image 281 finished...
# --------------------------------------------------
# Detection on image 282 finished...
# --------------------------------------------------
# Detection on image 283 finished...
# --------------------------------------------------
# Detection on image 284 finished...
# --------------------------------------------------
# Detection on image 285 finished...
# --------------------------------------------------
# Detection on image 286 finished...
# --------------------------------------------------
# Detection on image 287 finished...
# --------------------------------------------------
# Detection on image 288 finished...
# --------------------------------------------------
# Detection on image 289 finished...
# --------------------------------------------------
# Detection on image 290 finished...
# --------------------------------------------------
# Detection on image 291 finished...
# --------------------------------------------------
# Detection on image 292 finished...
# --------------------------------------------------
# Detection on image 293 finished...
# --------------------------------------------------
# Detection on image 294 finished...
# --------------------------------------------------
# Detection on image 295 finished...
# --------------------------------------------------
# Detection on image 296 finished...
# --------------------------------------------------
# Detection on image 297 finished...
# --------------------------------------------------
# Detection on image 298 finished...
# --------------------------------------------------
# Detection on image 299 finished...
# --------------------------------------------------
# Detection on image 300 finished...
# --------------------------------------------------
# Detection on image 301 finished...
# --------------------------------------------------
# Detection on image 302 finished...
# --------------------------------------------------
# Detection on image 303 finished...
# --------------------------------------------------
# Detection on image 304 finished...
# --------------------------------------------------
# Detection on image 305 finished...
# --------------------------------------------------
# Detection on image 306 finished...
# --------------------------------------------------
# Detection on image 307 finished...
# --------------------------------------------------
# Detection on image 308 finished...
# --------------------------------------------------
# Detection on image 309 finished...
# --------------------------------------------------
# Detection on image 310 finished...
# --------------------------------------------------
# Detection on image 311 finished...
# --------------------------------------------------
# Detection on image 312 finished...
# --------------------------------------------------
# Detection on image 313 finished...
# --------------------------------------------------
# Detection on image 314 finished...
# --------------------------------------------------
# Detection on image 315 finished...
# --------------------------------------------------
# Detection on image 316 finished...
# --------------------------------------------------
# Detection on image 317 finished...
# --------------------------------------------------
# Detection on image 318 finished...
# --------------------------------------------------
# Detection on image 319 finished...
# --------------------------------------------------
# Detection on image 320 finished...
# --------------------------------------------------
# Detection on image 321 finished...
# --------------------------------------------------
# Detection on image 322 finished...
# --------------------------------------------------
# Detection on image 323 finished...
# --------------------------------------------------
# Detection on image 324 finished...
# --------------------------------------------------
# Detection on image 325 finished...
# --------------------------------------------------
# Detection on image 326 finished...
# --------------------------------------------------
# Detection on image 327 finished...
# --------------------------------------------------
# Detection on image 328 finished...
# --------------------------------------------------
# Detection on image 329 finished...
# --------------------------------------------------
# Detection on image 330 finished...
# --------------------------------------------------
# Detection on image 331 finished...
# --------------------------------------------------
# Detection on image 332 finished...
# --------------------------------------------------
# Detection on image 333 finished...
# --------------------------------------------------
# Detection on image 334 finished...
# --------------------------------------------------
# Detection on image 335 finished...
# --------------------------------------------------
# Detection on image 336 finished...
# --------------------------------------------------
# Detection on image 337 finished...
# --------------------------------------------------
# Detection on image 338 finished...
# --------------------------------------------------
# Detection on image 339 finished...
# --------------------------------------------------
# Detection on image 340 finished...
# --------------------------------------------------
# Detection on image 341 finished...
# --------------------------------------------------
# Detection on image 342 finished...
# --------------------------------------------------
# Detection on image 343 finished...
# --------------------------------------------------
# Detection on image 344 finished...
# --------------------------------------------------
# Detection on image 345 finished...
# --------------------------------------------------
# Detection on image 346 finished...
# --------------------------------------------------
# Detection on image 347 finished...
# --------------------------------------------------
# Detection on image 348 finished...
# --------------------------------------------------
# Detection on image 349 finished...
# --------------------------------------------------
# Detection on image 350 finished...
# --------------------------------------------------
# Detection on image 351 finished...
# --------------------------------------------------
# Detection on image 352 finished...
# --------------------------------------------------
# Detection on image 353 finished...
# --------------------------------------------------
# Detection on image 354 finished...
# --------------------------------------------------
# Detection on image 355 finished...
# --------------------------------------------------
# Detection on image 356 finished...
# --------------------------------------------------
# Detection on image 357 finished...
# --------------------------------------------------
# Detection on image 358 finished...
# --------------------------------------------------
# Detection on image 359 finished...
# --------------------------------------------------
# Detection on image 360 finished...
# --------------------------------------------------
# Detection on image 361 finished...
# --------------------------------------------------
# Detection on image 362 finished...
# --------------------------------------------------
# Detection on image 363 finished...
# --------------------------------------------------
# Detection on image 364 finished...
# --------------------------------------------------
# Detection on image 365 finished...
# --------------------------------------------------
# Detection on image 366 finished...
# --------------------------------------------------
# Detection on image 367 finished...
# --------------------------------------------------
# Detection on image 368 finished...
# --------------------------------------------------
# Detection on image 369 finished...
# --------------------------------------------------
# Detection on image 370 finished...
# --------------------------------------------------
# Detection on image 371 finished...
# --------------------------------------------------
# Detection on image 372 finished...
# --------------------------------------------------
# Detection on image 373 finished...
# --------------------------------------------------
# Detection on image 374 finished...
# --------------------------------------------------
# Detection on image 375 finished...
# --------------------------------------------------
# Detection on image 376 finished...
# --------------------------------------------------
# Detection on image 377 finished...
# --------------------------------------------------
# Detection on image 378 finished...
# --------------------------------------------------
# Detection on image 379 finished...
# --------------------------------------------------
# Detection on image 380 finished...
# --------------------------------------------------
# Detection on image 381 finished...
# --------------------------------------------------
# Detection on image 382 finished...
# --------------------------------------------------
# Detection on image 383 finished...
# --------------------------------------------------
# Detection on image 384 finished...
# --------------------------------------------------
# Detection on image 385 finished...
# --------------------------------------------------
# Detection on image 386 finished...
# --------------------------------------------------
# Detection on image 387 finished...
# --------------------------------------------------
# Detection on image 388 finished...
# --------------------------------------------------
# Detection on image 389 finished...
# --------------------------------------------------
# Detection on image 390 finished...
# --------------------------------------------------
# Detection on image 391 finished...
# --------------------------------------------------
# Detection on image 392 finished...
# --------------------------------------------------
# Detection on image 393 finished...
# --------------------------------------------------
# Detection on image 394 finished...
# --------------------------------------------------
# Detection on image 395 finished...
# --------------------------------------------------
# Detection on image 396 finished...
# --------------------------------------------------
# Detection on image 397 finished...
# --------------------------------------------------
# Detection on image 398 finished...
# --------------------------------------------------
# Detection on image 399 finished...
# --------------------------------------------------
# Detection on image 400 finished...
# --------------------------------------------------
# Detection on image 401 finished...
# --------------------------------------------------
# Detection on image 402 finished...
# --------------------------------------------------
# Detection on image 403 finished...
# --------------------------------------------------
# Detection on image 404 finished...
# --------------------------------------------------
# Detection on image 405 finished...
# --------------------------------------------------
# Detection on image 406 finished...
# --------------------------------------------------
# Detection on image 407 finished...
# --------------------------------------------------
# Detection on image 408 finished...
# --------------------------------------------------
# Detection on image 409 finished...
# --------------------------------------------------
# Detection on image 410 finished...
# --------------------------------------------------
# Detection on image 411 finished...
# --------------------------------------------------
# Detection on image 412 finished...
# --------------------------------------------------
# Detection on image 413 finished...
# --------------------------------------------------
# Detection on image 414 finished...
# --------------------------------------------------
# Detection on image 415 finished...
# --------------------------------------------------
# Detection on image 416 finished...
# --------------------------------------------------
# Detection on image 417 finished...
# --------------------------------------------------
# Detection on image 418 finished...
# --------------------------------------------------
# Detection on image 419 finished...
# --------------------------------------------------
# Detection on image 420 finished...
# --------------------------------------------------
# Detection on image 421 finished...
# --------------------------------------------------
# Detection on image 422 finished...
# --------------------------------------------------
# Detection on image 423 finished...
# --------------------------------------------------
# Detection on image 424 finished...
# --------------------------------------------------
# Detection on image 425 finished...
# --------------------------------------------------
# Detection on image 426 finished...
# --------------------------------------------------
# Detection on image 427 finished...
# --------------------------------------------------
# Detection on image 428 finished...
# --------------------------------------------------
# Detection on image 429 finished...
# --------------------------------------------------
# Detection on image 430 finished...
# --------------------------------------------------
# Detection on image 431 finished...
# --------------------------------------------------
# Detection on image 432 finished...
# --------------------------------------------------
# Detection on image 433 finished...
# --------------------------------------------------
# Detection on image 434 finished...
# --------------------------------------------------
# Detection on image 435 finished...
# --------------------------------------------------
# Detection on image 436 finished...
# --------------------------------------------------
# Detection on image 437 finished...
# --------------------------------------------------
# Detection on image 438 finished...
# --------------------------------------------------
# Detection on image 439 finished...
# --------------------------------------------------
# Detection on image 440 finished...
# --------------------------------------------------
# Detection on image 441 finished...
# --------------------------------------------------
# Detection on image 442 finished...
# --------------------------------------------------
# Detection on image 443 finished...
# --------------------------------------------------
# Detection on image 444 finished...
# --------------------------------------------------
# Detection on image 445 finished...
# --------------------------------------------------
# Detection on image 446 finished...
# --------------------------------------------------
# Detection on image 447 finished...
# --------------------------------------------------
# Detection on image 448 finished...
# --------------------------------------------------
# Detection on image 449 finished...
# --------------------------------------------------
# Detection on image 450 finished...
# --------------------------------------------------
# Detection on image 451 finished...
# --------------------------------------------------
# Detection on image 452 finished...
# --------------------------------------------------
# Detection on image 453 finished...
# --------------------------------------------------
# Detection on image 454 finished...
# --------------------------------------------------
# Detection on image 455 finished...
# --------------------------------------------------
# Detection on image 456 finished...
# --------------------------------------------------
# Detection on image 457 finished...
# --------------------------------------------------
# Detection on image 458 finished...
# --------------------------------------------------
# Detection on image 459 finished...
# --------------------------------------------------
# Detection on image 460 finished...
# --------------------------------------------------
# Detection on image 461 finished...
# --------------------------------------------------
# Detection on image 462 finished...
# --------------------------------------------------
# Detection on image 463 finished...
# --------------------------------------------------
# Detection on image 464 finished...
# --------------------------------------------------
# Detection on image 465 finished...
# --------------------------------------------------
# Detection on image 466 finished...
# --------------------------------------------------
# Detection on image 467 finished...
# --------------------------------------------------
# Detection on image 468 finished...
# --------------------------------------------------
# Detection on image 469 finished...
# --------------------------------------------------
# Detection on image 470 finished...
# --------------------------------------------------
# Detection on image 471 finished...
# --------------------------------------------------
# Detection on image 472 finished...
# --------------------------------------------------
# Detection on image 473 finished...
# --------------------------------------------------
# Detection on image 474 finished...
# --------------------------------------------------
# Detection on image 475 finished...
# --------------------------------------------------
# Detection on image 476 finished...
# --------------------------------------------------
# Detection on image 477 finished...
# --------------------------------------------------
# Detection on image 478 finished...
# --------------------------------------------------
# Detection on image 479 finished...
# --------------------------------------------------
# Detection on image 480 finished...
# --------------------------------------------------
# Detection on image 481 finished...
# --------------------------------------------------
# Detection on image 482 finished...
# --------------------------------------------------
# Detection on image 483 finished...
# --------------------------------------------------
# Detection on image 484 finished...
# --------------------------------------------------
# Detection on image 485 finished...
# --------------------------------------------------
# Detection on image 486 finished...
# --------------------------------------------------
# Detection on image 487 finished...
# --------------------------------------------------
# Detection on image 488 finished...
# --------------------------------------------------
# Detection on image 489 finished...
# --------------------------------------------------
# Detection on image 490 finished...
# --------------------------------------------------
# Detection on image 491 finished...
# --------------------------------------------------
# Detection on image 492 finished...
# --------------------------------------------------
# Detection on image 493 finished...
# --------------------------------------------------
# Detection on image 494 finished...
# --------------------------------------------------
# Detection on image 495 finished...
# --------------------------------------------------
# Detection on image 496 finished...
# --------------------------------------------------
# Detection on image 497 finished...
# --------------------------------------------------
# Detection on image 498 finished...
# --------------------------------------------------
# Detection on image 499 finished...
# --------------------------------------------------
# Detection on image 500 finished...
# --------------------------------------------------
# Detection on image 501 finished...
# --------------------------------------------------
# Detection on image 502 finished...
# --------------------------------------------------
# Detection on image 503 finished...
# --------------------------------------------------
# Detection on image 504 finished...
# --------------------------------------------------
# Detection on image 505 finished...
# --------------------------------------------------
# Detection on image 506 finished...
# --------------------------------------------------
# Detection on image 507 finished...
# --------------------------------------------------
# Detection on image 508 finished...
# --------------------------------------------------
# Detection on image 509 finished...
# --------------------------------------------------
# Detection on image 510 finished...
# --------------------------------------------------
# Detection on image 511 finished...
# --------------------------------------------------
# Detection on image 512 finished...
# --------------------------------------------------
# Detection on image 513 finished...
# --------------------------------------------------
# Detection on image 514 finished...
# --------------------------------------------------
# Detection on image 515 finished...
# --------------------------------------------------
# Detection on image 516 finished...
# --------------------------------------------------
# Detection on image 517 finished...
# --------------------------------------------------
# Detection on image 518 finished...
# --------------------------------------------------
# Detection on image 519 finished...
# --------------------------------------------------
# Detection on image 520 finished...
# --------------------------------------------------
# Detection on image 521 finished...
# --------------------------------------------------
# Detection on image 522 finished...
# --------------------------------------------------
# Detection on image 523 finished...
# --------------------------------------------------
# Detection on image 524 finished...
# --------------------------------------------------
# Detection on image 525 finished...
# --------------------------------------------------
# Detection on image 526 finished...
# --------------------------------------------------
# Detection on image 527 finished...
# --------------------------------------------------
# Detection on image 528 finished...
# --------------------------------------------------
# Detection on image 529 finished...
# --------------------------------------------------
# Detection on image 530 finished...
# --------------------------------------------------
# Detection on image 531 finished...
# --------------------------------------------------
# Detection on image 532 finished...
# --------------------------------------------------
# Detection on image 533 finished...
# --------------------------------------------------
# Detection on image 534 finished...
# --------------------------------------------------
# Detection on image 535 finished...
# --------------------------------------------------
# Detection on image 536 finished...
# --------------------------------------------------
# Detection on image 537 finished...
# --------------------------------------------------
# Detection on image 538 finished...
# --------------------------------------------------
# Detection on image 539 finished...
# --------------------------------------------------
# Detection on image 540 finished...
# --------------------------------------------------
# Detection on image 541 finished...
# --------------------------------------------------
# Detection on image 542 finished...
# --------------------------------------------------
# Detection on image 543 finished...
# --------------------------------------------------
# Detection on image 544 finished...
# --------------------------------------------------
# Detection on image 545 finished...
# --------------------------------------------------
# Detection on image 546 finished...
# --------------------------------------------------
# Detection on image 547 finished...
# --------------------------------------------------
# Detection on image 548 finished...
# --------------------------------------------------
# Detection on image 549 finished...
# --------------------------------------------------
# Detection on image 550 finished...
# --------------------------------------------------
# Detection on image 551 finished...
# --------------------------------------------------
# Detection on image 552 finished...
# --------------------------------------------------
# Detection on image 553 finished...
# --------------------------------------------------
# Detection on image 554 finished...
# --------------------------------------------------
# Detection on image 555 finished...
# --------------------------------------------------
# Detection on image 556 finished...
# --------------------------------------------------
# Detection on image 557 finished...
# ...
# Detection on image 640 finished...
# --------------------------------------------------
# Detection on image 641 finished...
# --------------------------------------------------
# Detection on image 642 finished...
# --------------------------------------------------
# Detection on image 643 finished...
# --------------------------------------------------
# Detection on image 644 finished...
# --------------------------------------------------
# Detection on image 645 finished...
# --------------------------------------------------
# Detection on image 646 finished...
# --------------------------------------------------
# Detection on image 647 finished...
# --------------------------------------------------
# Detection on image 648 finished...
# --------------------------------------------------
# Detection on image 649 finished...
# --------------------------------------------------
# Detection on image 650 finished...
# --------------------------------------------------
# Detection on image 651 finished...
# --------------------------------------------------
# Detection on image 652 finished...
# --------------------------------------------------
# Detection on image 653 finished...
# --------------------------------------------------
# Detection on image 654 finished...
# --------------------------------------------------
# Detection on image 655 finished...
# --------------------------------------------------
# Detection on image 656 finished...
# --------------------------------------------------
# Detection on image 657 finished...
# --------------------------------------------------
# Detection on image 658 finished...
# --------------------------------------------------
# Detection on image 659 finished...
# --------------------------------------------------
# Detection on image 660 finished...
# --------------------------------------------------
# Detection on image 661 finished...
# --------------------------------------------------
# Detection on image 662 finished...
# --------------------------------------------------
# Detection on image 663 finished...
# --------------------------------------------------
# Detection on image 664 finished...
# --------------------------------------------------
# Detection on image 665 finished...
# --------------------------------------------------
# Detection on image 666 finished...
# --------------------------------------------------
# Detection on image 667 finished...
# --------------------------------------------------
# Detection on image 668 finished...
# --------------------------------------------------
# Detection on image 669 finished...
# --------------------------------------------------
# Detection on image 670 finished...
# --------------------------------------------------
# Detection on image 671 finished...
# --------------------------------------------------
# Detection on image 672 finished...
# --------------------------------------------------
# Detection on image 673 finished...
# --------------------------------------------------
# Detection on image 674 finished...
# --------------------------------------------------
# Detection on image 675 finished...
# --------------------------------------------------
# Detection on image 676 finished...
# --------------------------------------------------
# Detection on image 677 finished...
# --------------------------------------------------
# Detection on image 678 finished...
# --------------------------------------------------
# Detection on image 679 finished...
# --------------------------------------------------
# Detection on image 680 finished...
# --------------------------------------------------
# Detection on image 681 finished...
# --------------------------------------------------
# Detection on image 682 finished...
# --------------------------------------------------
# Detection on image 683 finished...
# --------------------------------------------------
# Detection on image 684 finished...
# --------------------------------------------------
# Detection on image 685 finished...
# --------------------------------------------------
# Detection on image 686 finished...
# --------------------------------------------------
# Detection on image 687 finished...
# --------------------------------------------------
# Detection on image 688 finished...
# --------------------------------------------------
# Detection on image 689 finished...
# --------------------------------------------------
# Detection on image 690 finished...
# --------------------------------------------------
# Detection on image 691 finished...
# --------------------------------------------------
# Detection on image 692 finished...
# --------------------------------------------------
# Detection on image 693 finished...
# --------------------------------------------------
# Detection on image 694 finished...
# --------------------------------------------------
# Detection on image 695 finished...
# --------------------------------------------------
# Detection on image 696 finished...
# --------------------------------------------------
# Detection on image 697 finished...
# --------------------------------------------------
# Detection on image 698 finished...
# --------------------------------------------------
# Detection on image 699 finished...
# --------------------------------------------------
# Detection on image 700 finished...
# --------------------------------------------------
# Detection on image 701 finished...
# --------------------------------------------------
# Detection on image 702 finished...
# --------------------------------------------------
# Detection on image 703 finished...
# --------------------------------------------------
# Detection on image 704 finished...
# --------------------------------------------------
# Detection on image 705 finished...
# --------------------------------------------------
# Detection on image 706 finished...
# --------------------------------------------------
# Detection on image 707 finished...
# --------------------------------------------------
# Detection on image 708 finished...
# --------------------------------------------------
# Detection on image 709 finished...
# --------------------------------------------------
# Detection on image 710 finished...
# --------------------------------------------------
# Detection on image 711 finished...
# --------------------------------------------------
# Detection on image 712 finished...
# --------------------------------------------------
# Detection on image 713 finished...
# --------------------------------------------------
# Detection on image 714 finished...
# --------------------------------------------------
# Detection on image 715 finished...
# --------------------------------------------------
# Detection on image 716 finished...
# --------------------------------------------------
# Detection on image 717 finished...
# --------------------------------------------------
# Detection on image 718 finished...
# --------------------------------------------------
# Detection on image 719 finished...
# --------------------------------------------------
# Detection on image 720 finished...
# --------------------------------------------------
# Detection on image 721 finished...
# --------------------------------------------------
# Detection on image 722 finished...
# --------------------------------------------------
# Detection on image 723 finished...
# --------------------------------------------------
# Detection on image 724 finished...
# --------------------------------------------------
# Detection on image 725 finished...
# --------------------------------------------------
# Detection on image 726 finished...
# --------------------------------------------------
# Detection on image 727 finished...
# --------------------------------------------------
# Detection on image 728 finished...
# --------------------------------------------------
# Detection on image 729 finished...
# --------------------------------------------------
# Detection on image 730 finished...
# --------------------------------------------------
# Detection on image 731 finished...
# --------------------------------------------------
# Detection on image 732 finished...
# --------------------------------------------------
# Detection on image 733 finished...
# --------------------------------------------------
# Detection on image 734 finished...
# --------------------------------------------------
# Detection on image 735 finished...
# --------------------------------------------------
# Detection on image 736 finished...
# --------------------------------------------------
# Detection on image 737 finished...
# --------------------------------------------------
# Detection on image 738 finished...
# --------------------------------------------------
# Detection on image 739 finished...
# --------------------------------------------------
# Detection on image 740 finished...
# --------------------------------------------------
# Detection on image 741 finished...
# --------------------------------------------------
# Detection on image 742 finished...
# --------------------------------------------------
# Detection on image 743 finished...
# --------------------------------------------------
# Detection on image 744 finished...
# --------------------------------------------------
# Detection on image 745 finished...
# --------------------------------------------------
# Detection on image 746 finished...
# --------------------------------------------------
# Detection on image 747 finished...
# --------------------------------------------------
# Detection on image 748 finished...
# --------------------------------------------------
# Detection on image 749 finished...
# --------------------------------------------------
# Detection on image 750 finished...
# --------------------------------------------------
# Detection on image 751 finished...
# --------------------------------------------------
# Detection on image 752 finished...
# --------------------------------------------------
# Detection on image 753 finished...
# --------------------------------------------------
# Detection on image 754 finished...
# --------------------------------------------------
# Detection on image 755 finished...
# --------------------------------------------------
# Detection on image 756 finished...
# --------------------------------------------------
# Detection on image 757 finished...
# --------------------------------------------------
# Detection on image 758 finished...
# --------------------------------------------------
# Detection on image 759 finished...
# --------------------------------------------------
# Detection on image 760 finished...
# --------------------------------------------------
# Detection on image 761 finished...
# --------------------------------------------------
# Detection on image 762 finished...
# --------------------------------------------------
# Detection on image 763 finished...
# --------------------------------------------------
# Detection on image 764 finished...
# --------------------------------------------------
# Detection on image 765 finished...
# --------------------------------------------------
# Detection on image 766 finished...
# --------------------------------------------------
# Detection on image 767 finished...
# --------------------------------------------------
# Detection on image 768 finished...
# --------------------------------------------------
# Detection on image 769 finished...
# --------------------------------------------------
# Detection on image 770 finished...
# --------------------------------------------------
# Detection on image 771 finished...
# --------------------------------------------------
# Detection on image 772 finished...
# --------------------------------------------------
# Detection on image 773 finished...
# --------------------------------------------------
# Detection on image 774 finished...
# --------------------------------------------------
# Detection on image 775 finished...
# --------------------------------------------------
# Detection on image 776 finished...
# --------------------------------------------------
# Detection on image 777 finished...
# --------------------------------------------------
# Detection on image 778 finished...
# --------------------------------------------------
# Detection on image 779 finished...
# --------------------------------------------------
# Detection on image 780 finished...
# --------------------------------------------------
# Detection on image 781 finished...
# --------------------------------------------------
# Detection on image 782 finished...
# --------------------------------------------------
# Detection on image 783 finished...
# --------------------------------------------------
# Detection on image 784 finished...
# --------------------------------------------------
# Detection on image 785 finished...
# --------------------------------------------------
# Detection on image 786 finished...
# --------------------------------------------------
# Detection on image 787 finished...
# --------------------------------------------------
# Detection on image 788 finished...
# --------------------------------------------------
# Detection on image 789 finished...
# --------------------------------------------------
# Detection on image 790 finished...
# --------------------------------------------------
# Detection on image 791 finished...
# --------------------------------------------------
# Detection on image 792 finished...
# --------------------------------------------------
# Detection on image 793 finished...
# --------------------------------------------------
# Detection on image 794 finished...
# --------------------------------------------------
# Detection on image 795 finished...
# --------------------------------------------------
# Detection on image 796 finished...
# --------------------------------------------------
# Detection on image 797 finished...
# --------------------------------------------------
# Detection on image 798 finished...
# --------------------------------------------------
# Detection on image 799 finished...
# --------------------------------------------------
# Detection on image 800 finished...
# --------------------------------------------------
# Detection on image 801 finished...
# --------------------------------------------------
# Detection on image 802 finished...
# --------------------------------------------------
# Detection on image 803 finished...
# --------------------------------------------------
# Detection on image 804 finished...
# --------------------------------------------------
# Detection on image 805 finished...
# --------------------------------------------------
# Detection on image 806 finished...
# --------------------------------------------------
# Detection on image 807 finished...
# --------------------------------------------------
# Detection on image 808 finished...
# --------------------------------------------------
# Detection on image 809 finished...
# --------------------------------------------------
# Detection on image 810 finished...
# --------------------------------------------------
# Detection on image 811 finished...
# --------------------------------------------------
# Detection on image 812 finished...
# --------------------------------------------------
# Detection on image 813 finished...
# --------------------------------------------------
# Detection on image 814 finished...
# --------------------------------------------------
# Detection on image 815 finished...
# --------------------------------------------------
# Detection on image 816 finished...
# --------------------------------------------------
# Detection on image 817 finished...
# --------------------------------------------------
# Detection on image 818 finished...
# --------------------------------------------------
# Detection on image 819 finished...
# --------------------------------------------------
# Detection on image 820 finished...
# --------------------------------------------------
# Detection on image 821 finished...
# --------------------------------------------------
# Detection on image 822 finished...
# --------------------------------------------------
# Detection on image 823 finished...
# --------------------------------------------------
# Detection on image 824 finished...
# --------------------------------------------------
# Dataset detection completed.
# Average FPS: 23.668

# %% [markdown]
# ## Inference on videos

# %%
def detect_video(video_path, model, output_dir='.', detection_threshold=0.8, save_video=True):
    """
    Carries out detection on a video frame by frame, showing it in real time in an opencv window and showing the framerate. 
    It also saves the video at 30 fps as a .mp4
    """
    # set model confidence score threshold
    model.conf = detection_threshold
    # start videocaptures
    cap = cv2.VideoCapture(video_path)
    
    if (cap.isOpened() == False):
        print('Error while trying to read video. Please check path again')
    
    # get the frame width and height
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    
    save_name = f"{video_path.split('/')[-1].split('.')[0]}"
    # define codec and create VideoWriter object
    if save_video:
        out = cv2.VideoWriter(f"{output_dir}/{save_name}.mp4",
                             cv2.VideoWriter_fourcc(*'mp4v'), 30,
                             (frame_width, frame_height))
    
    frame_count = 0 # to count total frames
    total_fps = 0 # to get the final frames per second
    
    # Reading Frames and Detecting Objects
    # read until end of video
    while(cap.isOpened()):
        # capture each frame of the video
        ret, frame = cap.read()
        # while the video isn't finished...
        if ret:
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            #image = Image.fromarray((image).astype(np.uint8)).convert("RGB")
            with torch.no_grad():
                # get predictions for the current frame
                results_df, inf_time = predict(image, model)
            
            # draw boxes and show current frame on screen
            image = draw_boxes(results_df, image)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            # get the inference time fps
            fps = 1 / inf_time
            # add fps tot total fps
            total_fps += fps
            # increment frame count
            frame_count += 1
            image = cv2.putText(image, f"{fps:.1f} FPS", 
                        (image.shape[1]-200, 25),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 
                        2, lineType=cv2.LINE_AA)
            
            # Display frames in a window
            # press 'q' to exit
            wait_time = max(1, int(fps/4))
            cv2.imshow('image', image)
            if save_video:
                out.write(image)
            if cv2.waitKey(wait_time) & 0xFF == ord('q'):
                break
                
        else:
            break
      
    # release VideoCapture()
    cap.release()
    # close all frames and video windows
    cv2.destroyAllWindows()
    
    # calculate and print the average fps
    avg_fps = total_fps / frame_count
    print(f"Average FPS: {avg_fps:.3f}")

# %% [markdown]
# ### YOLOV5s small model

# %%
folder_name = 'validation_video_YOLOv5s_model_1'
# %cd {INFERENCE_OUTPUT_DIR}
# !mkdir {folder_name}
# %cd ..
video_path = f"{VIDEOS_DIR}/validation/2205_Luderick_25.mov"
output_dir = f"{INFERENCE_OUTPUT_DIR}/{folder_name}"

detect_video(video_path, model_s, output_dir, detection_threshold=0.6, save_video=True)
torch.cuda.empty_cache()
# Out:
# C:\Users\Ricard\Desktop\Master\TFM\notebooks\Luderick_Seagrass\inference_outputs
# C:\Users\Ricard\Desktop\Master\TFM\notebooks\Luderick_Seagrass
# Ya existe el subdirectorio o el archivo validation_video_YOLOv5s_model_1.
# Average FPS: 43.738

# %% [markdown]
# ### YOLOV5m medium model

# %%
folder_name = 'validation_video_YOLOv5m_model_1'
# %cd {INFERENCE_OUTPUT_DIR}
# !mkdir {folder_name}
# %cd ..
video_path = f"{VIDEOS_DIR}/validation/2205_Luderick_25.mov"
output_dir = f"{INFERENCE_OUTPUT_DIR}/{folder_name}"

detect_video(video_path, model_m, output_dir, detection_threshold=0.6, save_video=True)
torch.cuda.empty_cache()
# Out:
# C:\Users\Ricard\Desktop\Master\TFM\notebooks\Luderick_Seagrass\inference_outputs
# C:\Users\Ricard\Desktop\Master\TFM\notebooks\Luderick_Seagrass
# Ya existe el subdirectorio o el archivo validation_video_YOLOv5m_model_1.
# Average FPS: 33.749

# %% [markdown]
# ### YOLOv5l large model

# %%
folder_name = 'validation_video_YOLOv5l_model_1'
# %cd {INFERENCE_OUTPUT_DIR}
# !mkdir {folder_name}
# %cd ..
video_path = f"{VIDEOS_DIR}/validation/2205_Luderick_25.mov"
output_dir = f"{INFERENCE_OUTPUT_DIR}/{folder_name}"

detect_video(video_path, model_l, output_dir, detection_threshold=0.6, save_video=True)
torch.cuda.empty_cache()
# Out:
# C:\Users\Ricard\Desktop\Master\TFM\notebooks\Luderick_Seagrass\inference_outputs
# C:\Users\Ricard\Desktop\Master\TFM\notebooks\Luderick_Seagrass
# Average FPS: 21.418

# %% [markdown]
# ### Average FPS for each YOLOv5 model size option:
#
# * YOLOv5s (small) = 43.7 fps
# * YOLOv5m (medium) = 33.7 fps
# * YOLO v5l (large) = 21.4 fps

# %% [markdown]
# ## Model Evaluation using Mean Average Precision (mAP)

# %% [markdown]
# ### Function to compute the Intersection Over Union (IOU)
#
# The IOU is the ratio between the area of the intersection between two boxes and the area of their union

# %%
def IOU(box_1, box_2):
    """
    Computes the Intersection Over Union (IOU) between two bounding boxes formatted as [x_min, y_min, x_max, y_max]
    """
    # get the right-most left edge between the two bounding boxes
    max_left = max(box_1[0], box_2[0])
    # get the left-most right edge between the two bounding boxes
    min_right = min(box_1[2], box_2[2])
    # compute the intersection width
    intersection_width = min_right - max_left
    
    # get the lowest top edge (y is bigger as it goes lower)
    max_top = max(box_1[1], box_2[1])
    # get the highest bottom edge
    min_bottom = min(box_1[3], box_2[3])
    # compute the intersection height
    intersection_height = min_bottom - max_top
    
    # if the boxes don't intersect, intersection_width or height will be negative
    intersection_area = max(0, intersection_width) * max(0, intersection_height)
    box_1_area = (box_1[2] - box_1[0]) * (box_1[3] - box_1[1])
    box_2_area = (box_2[2] - box_2[0]) * (box_2[3] - box_2[1])
    # get the union area by adding the boxes areas and substracting their intersection
    union_area = box_1_area + box_2_area - intersection_area
    # get the final iou
    iou = intersection_area / union_area
    
    return iou

# %% [markdown]
# ### Functions to generate a dataframe with info of each predicted bounding box
# It includes:
#  * Name of the image where the predicted box is
#  * Label id of the prediction (class id)
#  * Confidence score of the prediction
#  * The ground truth box id (in respect to the image) with the highest IOU (-1 if none found)
#  * The highest IOU with any ground truth box

# %%
def get_image_box_evaluation_dataframe(results_df, true_boxes, true_labels):
    """
    Returns the box evaluation dataframe of a single image and class
    """
    ious_gt_box_index = np.array([-1] * len(results_df))
    ious = np.zeros(len(results_df))
    pred_scores = results_df['confidence'].values
    for index, row in results_df.iterrows():
        max_iou = 0
        max_iou_box_index = -1
        pred_box = [row['xmin'], row['ymin'], row['xmax'], row['ymax']]
        pred_label = row['class']
        for j, true_box in enumerate(true_boxes):
            iou = IOU(pred_box, true_box)
            # substract 1 to true label indices as yolo does not have the background class
            # luderick class label = 0
            if iou > max_iou and (true_labels[j]-1) == pred_label:
                max_iou = iou
                # save the index of the true box with highest iou
                max_iou_box_index = j
        
        ious[index] = max_iou
        ious_gt_box_index[index] = max_iou_box_index

    output_df = pd.DataFrame({'confidence': pred_scores,'IOU': ious,'GT_Box': ious_gt_box_index})
    
    return output_df

# %%
def get_boxes_evaluation_dataframe(model, luderick_df, images_dir, num_classes, detection_threshold):
    """
    Returns the box evaluation dataframe
    """
    image_names = luderick_df['image_name'].values
    num_images = len(image_names)
    all_boxes_eval_df = pd.DataFrame()
    
    # set model confidence score threshold
    model.conf = detection_threshold
    for i, image_name in enumerate(image_names):
        if i % int(num_images/4) == 0:
            print(f'{(i/num_images)*100}% of images processed')
        # load the image
        image = Image.open(f"{images_dir}/{image_name}").convert('RGB') 
        # use the model to get the predictions
        results_df, inf_time = predict(image, model)
        true_boxes = luderick_df.iloc[i]['bounding_boxes']
        true_labels = luderick_df.iloc[i]['labels']
        for label in range(num_classes):
            # use the rows from results_df with predicted class = label
            image_boxes_eval_df = get_image_box_evaluation_dataframe(results_df[results_df['class'] == label], 
                                            true_boxes, true_labels)
            image_boxes_eval_df['image_name'] = [image_name]*len(image_boxes_eval_df)
            image_boxes_eval_df['label_id'] = [label]*len(image_boxes_eval_df)
            image_boxes_eval_df = image_boxes_eval_df[['image_name', 'label_id', 'confidence', 'GT_Box', 'IOU']]
            all_boxes_eval_df = pd.concat([all_boxes_eval_df, image_boxes_eval_df], ignore_index=True)
    
    print('100% of images processed')
    
    return all_boxes_eval_df

# %%
box_eval_df = get_boxes_evaluation_dataframe(model_m, validation_df, IMAGES_DIR, NUM_CLASSES, detection_threshold=0.01)
# Out:
# 0.0% of images processed
# 25.0% of images processed
# 50.0% of images processed
# 75.0% of images processed
# 100% of images processed

# %%
box_eval_df
# Out:
#                        image_name  label_id  confidence  GT_Box       IOU
# 0     04C2_Luderick_16_000400.jpg         0    0.861667       0  0.853686
# 1     04C2_Luderick_16_000400.jpg         0    0.055639       0  0.335362
# 2     04C2_Luderick_16_000400.jpg         0    0.044432      -1  0.000000
# 3     04C2_Luderick_16_000600.jpg         0    0.913236       0  0.886129
# 4     04C2_Luderick_16_000600.jpg         0    0.026711      -1  0.000000
# ...                           ...       ...         ...     ...       ...
# 3656     brim.mov_5fps_000002.jpg         0    0.016778      -1  0.000000
# 3657     brim.mov_5fps_000002.jpg         0    0.016774      -1  0.000000
# 3658     brim.mov_5fps_000002.jpg         0    0.014656      -1  0.000000
# 3659     brim.mov_5fps_000002.jpg         0    0.011150      -1  0.000000
# 3660     brim.mov_5fps_000002.jpg         0    0.010556      -1  0.000000
#
# [3661 rows x 5 columns]

# %% [markdown]
# ### Assign True Positive or False Positive
#
# Given a IOU threshold, if the IOU is above that threshold, the predicted box will be considered a true positive (TP = 1) or False Positve (TP = 0) otherwise

# %%
def assign_tp_fp(boxes_eval_df, iou_thresh):
    """
    Check if every predicted box is a true positive (TP) or a false positive (FP) for a given IOU threshold
    and set the TP column to 1 or 0 accordingly
    """
    boxes_eval_df = boxes_eval_df.sort_values(by='confidence', ascending=False)
    boxes_eval_df = boxes_eval_df.reset_index(drop=True)
    gt_boxes_checked = []
    for index, row in boxes_eval_df.iterrows():
        gt_box_id = f"{row['image_name']}_box_{row['GT_Box']}"
        # assignt TP if the pred_box intersects with a GT box and has higher IOU than the threshold
        if row['GT_Box'] != -1 \
            and row['IOU'] > iou_thresh \
                and not(gt_box_id in gt_boxes_checked): # dont mark as TP if another pred_box is TP on the same GT box
                    boxes_eval_df.at[index, 'TP'] = 1
                    gt_boxes_checked.append(gt_box_id)
                    
        else:
            ## add false positive
            boxes_eval_df.at[index, 'TP'] = 0
    
    return boxes_eval_df

# %%
TP_df = assign_tp_fp(box_eval_df, 0.5)
TP_df
# Out:
#                                 image_name  label_id  confidence  GT_Box  \
# 0     2205_Luderick_20.mov_5fps_000106.jpg         0    0.964715       0
# 1     2205_Luderick_25.mov_5fps_000044.jpg         0    0.959894       3
# 2              04C2_Luderick_16_006400.jpg         0    0.955473       0
# 3     2205_Luderick_20.mov_5fps_000066.jpg         0    0.954832       0
# 4     2205_Luderick_25.mov_5fps_000063.jpg         0    0.954580       1
# ...                                    ...       ...         ...     ...
# 3656  04C4_Luderick_25.mov_5fps_000021.jpg         0    0.010044      -1
# 3657  2205_Luderick_25.mov_5fps_000048.jpg         0    0.010026       1
# 3658  04C2_Luderick_29.mov_5fps_000001.jpg         0    0.010024      -1
# 3659  27C3_Luderick_30.mov_5fps_000029.jpg         0    0.010022       0
# 3660   05C4_Luderick_1.mov_5fps_000002.jpg         0    0.010017       0
#
#            IOU   TP
# 0     0.886491  1.0
# 1     0.957778  1.0
# 2     0.920722  1.0
# 3     0.943238  1.0
# 4     0.928851  1.0
# ...        ...  ...
# 3656  0.000000  0.0
# 3657  0.075032  0.0
# 3658  0.000000  0.0
# 3659  0.060879  0.0
# 3660  0.086114  0.0
#
# [3661 rows x 6 columns]

# %% [markdown]
# ### Compute precision and recall for a given class
#
#  *  The precision is the ratio of predicted true positives between all the predicted positives.
#         * precision = true_positives / (true_positives + false_positives)
#
#  * The recall is the ratio of predicted true positives between all the ground truth positives.
#         * recall = true_positives / (true_positives + false_negatives) = true_positives / num_gt_boxes
#
# Both are computed step by step, starting from the highest confidence score predicted box

# %%
def assign_class_precision_recall(TP_df, class_id, num_gt_boxes):
    """
    Assign precision and recall ot the dataframe iteratively
    """
    # use only the boxes with the deriser class label
    prec_rec_df = TP_df[TP_df['label_id'] == class_id]
    prec_rec_df = prec_rec_df.sort_values(by='confidence', ascending=False)
    prec_rec_df = prec_rec_df.reset_index(drop=True)
    
    tp_count = 0
    for index, row in prec_rec_df.iterrows():
        # increase the total true positive count
        tp_count += row['TP']
        
        # precision = true positives / (true positives + false positves)
        # each row is either a true positives or a false positive, 
        # so precision = tp_count / index+1
        prec_rec_df.at[index, 'Precision'] = tp_count / (index+1)
        
        # recall = true positives / num_gt_boxes
        prec_rec_df.at[index, 'Recall'] = tp_count / num_gt_boxes
  
    return prec_rec_df

# %%
def get_total_gt_boxes(luderick_preprocessed_df, class_id):
    """
    Returns the total number of ground truth boxes in a luderick preprocessed dataframe with a given class id
    """
    # get how many gt boxes of that class_id appear in each image
    # substract 1 to label id from the preprocessed dataset
    gt_boxes_per_image = [np.count_nonzero((np.array(x)-1) == class_id) for x in luderick_preprocessed_df['labels'].values]
    # add all the results to get the total gt boxes of that class
    return sum(gt_boxes_per_image)

# %%
# get the total gt boxes in validation_df for the luderick class (label=1)
num_gt_boxes = get_total_gt_boxes(validation_df, 0)
print(f'Num gt boxes = {num_gt_boxes}')
# get the precision-recall dataframe
prec_rec_df = assign_class_precision_recall(TP_df, 0, num_gt_boxes)
prec_rec_df
# Out:
# Num gt boxes = 1632
#                                 image_name  label_id  confidence  GT_Box  \
# 0     2205_Luderick_20.mov_5fps_000106.jpg         0    0.964715       0
# 1     2205_Luderick_25.mov_5fps_000044.jpg         0    0.959894       3
# 2              04C2_Luderick_16_006400.jpg         0    0.955473       0
# 3     2205_Luderick_20.mov_5fps_000066.jpg         0    0.954832       0
# 4     2205_Luderick_25.mov_5fps_000063.jpg         0    0.954580       1
# ...                                    ...       ...         ...     ...
# 3656  04C4_Luderick_25.mov_5fps_000021.jpg         0    0.010044      -1
# 3657  2205_Luderick_25.mov_5fps_000048.jpg         0    0.010026       1
# 3658  04C2_Luderick_29.mov_5fps_000001.jpg         0    0.010024      -1
# 3659  27C3_Luderick_30.mov_5fps_000029.jpg         0    0.010022       0
# 3660   05C4_Luderick_1.mov_5fps_000002.jpg         0    0.010017       0
#
#            IOU   TP  Precision    Recall
# 0     0.886491  1.0   1.000000  0.000613
# 1     0.957778  1.0   1.000000  0.001225
# 2     0.920722  1.0   1.000000  0.001838
# 3     0.943238  1.0   1.000000  0.002451
# 4     0.928851  1.0   1.000000  0.003064
# ...        ...  ...        ...       ...
# 3656  0.000000  0.0   0.433962  0.972426
# 3657  0.075032  0.0   0.433844  0.972426
# 3658  0.000000  0.0   0.433725  0.972426
# 3659  0.060879  0.0   0.433607  0.972426
# 3660  0.086114  0.0   0.433488  0.972426
#
# [3661 rows x 8 columns]

# %%
# plot the precision recall curve

# %matplotlib inline
plt.plot(prec_rec_df['Recall'], prec_rec_df['Precision'])
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.title('Precision-Recall Curve with IOU threshold = 0.5')
plt.show();

# %% [markdown]
# ### Function to get the final class Precision and Recall dataframe given a box_eval_df and an IOU threshold

# %%
def get_threshold_prec_recall(box_eval_df, iou_threshold, class_id, num_gt_boxes):
    """
    Returns the final Precision and Recall dataframe given a box_eval_df and an IOU threshold   
    """
    out_df = assign_tp_fp(box_eval_df, iou_threshold)
    out_df = assign_class_precision_recall(out_df, class_id, num_gt_boxes)
    return out_df

# %%
# get the total gt boxes in validation_df for the luderick class (label=1) at different iou thresholds
num_gt_boxes = get_total_gt_boxes(validation_df, 0)
thres_prec_rec_df_50 = get_threshold_prec_recall(box_eval_df, 0.5, 0, num_gt_boxes)
thres_prec_rec_df_60 = get_threshold_prec_recall(box_eval_df, 0.6, 0, num_gt_boxes)
thres_prec_rec_df_70 = get_threshold_prec_recall(box_eval_df, 0.7, 0, num_gt_boxes)
thres_prec_rec_df_80 = get_threshold_prec_recall(box_eval_df, 0.8, 0, num_gt_boxes)
thres_prec_rec_df_90 = get_threshold_prec_recall(box_eval_df, 0.9, 0, num_gt_boxes)

# %%
# plot the precision recall curve
plt.plot(thres_prec_rec_df_50['Recall'], thres_prec_rec_df_50['Precision'], label = 'IOU > 0.5')
plt.plot(thres_prec_rec_df_60['Recall'], thres_prec_rec_df_60['Precision'], label = 'IOU > 0.6')
plt.plot(thres_prec_rec_df_70['Recall'], thres_prec_rec_df_70['Precision'], label = 'IOU > 0.7')
plt.plot(thres_prec_rec_df_80['Recall'], thres_prec_rec_df_80['Precision'], label = 'IOU > 0.8')
plt.plot(thres_prec_rec_df_90['Recall'], thres_prec_rec_df_90['Precision'], label = 'IOU > 0.9')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.title('Precision-Recall Curve with different IOU thresholds (Luderick class)')
plt.legend()
plt.show();

# %% [markdown]
# ### Average Precision (AP)
#
# The AP is equal to the numerical integration of the Precision-Recall curve = area under the curve.

# %%
def compute_trapezoid_integral(point_a, point_b):
    """
    Computes the trapezoidal numerical integration between two points
    Which is the area of the trapezoid formed by the two points and the x-axis
    where the altitude is (point_b_x - point_a_x) and point_a_y and point_b_y are the two bases
    area_trapezoid = (1/2)*(point_b_x - point_a_x)*(point_a_y + point_b_y)
    """
    return (1/2)*(point_b[0] - point_a[0])*(point_a[1] + point_b[1])

# %%
def compute_class_AP(precision_list, recall_list):
    """
    Returns the average precision of a class with a list of precisions and recalls as input
    """
    total_ap = 0
    # start at i = 1 as the trapezoidal rule needs the previous point
    for i in range(1, len(precision_list)):
        # recall is the x-axis and precision the y_axis
        point_a = (recall_list[i-1], precision_list[i-1])
        point_b = (recall_list[i], precision_list[i])
        # compute the area under the two points
        ap = compute_trapezoid_integral(point_a, point_b)
        # add to the total area
        total_ap += ap
    
    return total_ap

# %%
ap_50 = compute_class_AP(thres_prec_rec_df_50['Precision'], thres_prec_rec_df_50['Recall'])
ap_60 = compute_class_AP(thres_prec_rec_df_60['Precision'], thres_prec_rec_df_60['Recall'])
ap_70 = compute_class_AP(thres_prec_rec_df_70['Precision'], thres_prec_rec_df_70['Recall'])
ap_80 = compute_class_AP(thres_prec_rec_df_80['Precision'], thres_prec_rec_df_80['Recall'])
ap_90 = compute_class_AP(thres_prec_rec_df_90['Precision'], thres_prec_rec_df_90['Recall'])
print(f'(IOU > 0.5) AP = {ap_50}')
print(f'(IOU > 0.6) AP = {ap_60}')
print(f'(IOU > 0.7) AP = {ap_70}')
print(f'(IOU > 0.8) AP = {ap_80}')
print(f'(IOU > 0.9) AP = {ap_90}')
# Out:
# (IOU > 0.5) AP = 0.9344998578892131
# (IOU > 0.6) AP = 0.9101429465133538
# (IOU > 0.7) AP = 0.8353489472690536
# (IOU > 0.8) AP = 0.6244940297103425
# (IOU > 0.9) AP = 0.1651630267636338

# %% [markdown]
# ### Mean Average Precision (mAP)
#
#  * For each class, get the AP at different IOU thresholds (by recomputing the True Positives) and calculate its mean
#      * The general IOU threshold range for mAP computation is from 0.5 to 0.95 with step=0.05 (COCO dataset evaluation)
#      * The mAPs single IOU thresholds of 0.5 and 0.75 are usually used as well to
#  * Calculate the mean between the results of each class

# %%
def compute_mAp(box_eval_df, preprocessed_df, num_classes):
    """
    Returns the following metrics of a given box evaluation dataframe and the original preprocessed dataframe:
    - mAP@0.5:0.05:0.95
    - mAp@.50
    - mAP@.75 
    """
    # initialize the trhesholds array [0.5, 0.55, ... 0.90, 0.95]
    iou_thresholds = np.arange(0.5, 1, step=0.05)
    
    class_mAP_list = []
    class_mAP50_list = []
    class_mAP75_list = []
    # iterate over the classes
    for i in range(0, num_classes):
        iou_trheshold_ap_list = []
        num_gt_boxes = get_total_gt_boxes(preprocessed_df, i)
        for iou_threshold in iou_thresholds:
            # get the precision-recall dataframe
            prec_rec_df = get_threshold_prec_recall(box_eval_df, iou_threshold, i, num_gt_boxes)
            # get the average precision for this threshold
            ap = compute_class_AP(prec_rec_df['Precision'], prec_rec_df['Recall'])
            iou_trheshold_ap_list.append(ap)
            
        # get the mean of all the threshold APs and add it to the class_mAP list
        class_mAP = sum(iou_trheshold_ap_list) / len(iou_trheshold_ap_list)
        class_mAP_list.append(class_mAP)
        # save the mAP with IOU threshold = 0.5 to its class mAP@50 list
        class_mAP50_list.append(iou_trheshold_ap_list[0])
        # save the mAP with IOU threshold = 0.75 to its class mAP@50 list
        class_mAP75_list.append(iou_trheshold_ap_list[5])
    
    # get the final mAP by computing the mean of all the class mAPs
    mAP = sum(class_mAP_list) / len(class_mAP_list)
    mAP50 = sum(class_mAP50_list) / len(class_mAP50_list)
    mAP75 = sum(class_mAP75_list) / len(class_mAP75_list)
    # multiply by 100 to be in percentage format
    mAP *= 100
    mAP50 *= 100
    mAP75 *= 100
    return mAP, mAP50, mAP75

# %%
mAP, mAP50, mAP75 = compute_mAp(box_eval_df, validation_df, NUM_CLASSES)
print(f'Mean Average Precision')
print(f'mAP@0.5:0.05:0.95 = {mAP:.2f}')
print(f'mAp@.50 = {mAP50:.2f}')
print(f'mAp@.75 = {mAP75:.2f}')
# Out:
# Mean Average Precision
# mAP@0.5:0.05:0.95 = 64.72
# mAp@.50 = 93.45
# mAp@.75 = 75.06

# %% [markdown]
# ### Final model mAP evaluation function
#
# Include all the functions in a single function that only needs the model and the preprocessed Dataset

# %%
def evaluate_model_mAP(model, preprocessed_df, num_classes, images_dir):
    """
    Returns the Mean Average Precision (mAP) metrics of an object detection model on a apreprocessed dataframe 
    with the number of classes and images directory as extra parameters
    """
    print("Starting detection on images...")
    start_time = time.time()
    # get the box evaluation dataframe with a low detection threshold
    box_eval_df = get_boxes_evaluation_dataframe(model, preprocessed_df, images_dir, num_classes, detection_threshold=0.01)
    print("Finished image processing")
    print("Starting mAP evaluation...")
    # get the mAP
    mAP, mAP50, mAP75 = compute_mAp(box_eval_df, preprocessed_df, num_classes)
    end_time = time.time()
    print ('Evaluation finished')
    final_time = end_time - start_time
    print(f'Evaluation time = {final_time:.2f} seconds')
    print('-'*50)
    print(f'Mean Average Precision')
    print(f'mAP@0.5:0.05:0.95 = {mAP:.2f}')
    print(f'mAp@.50 = {mAP50:.2f}')
    print(f'mAp@.75 = {mAP75:.2f}')
    print('-'*50)
    torch.cuda.empty_cache()
    metrics_dict = {}
    metrics_dict['mAP@0.5:0.05:0.95'] = mAP
    metrics_dict['mAP@0.50'] = mAP50
    metrics_dict['mAP@0.75'] = mAP75
    return metrics_dict

# %%
metrics = evaluate_model_mAP(model_m, validation_df, NUM_CLASSES, IMAGES_DIR)
# Out:
# Starting detection on images...
# 0.0% of images processed
# 25.0% of images processed
# 50.0% of images processed
# 75.0% of images processed
# 100% of images processed
# Finished image processing
# Starting mAP evaluation...
# Evaluation finished
# Evaluation time = 60.16 seconds
# --------------------------------------------------
# Mean Average Precision
# mAP@0.5:0.05:0.95 = 64.72
# mAp@.50 = 93.45
# mAp@.75 = 75.06
# --------------------------------------------------

# %% [markdown]
# ## Evaluating and comparing different models and dataset splits

# %% [markdown]
# ### YOLOv5s small size

# %%
# Evaluate YOLOv5s

# validation dataset
print('YOLOv5s Evaluation')
print('-'*50)

# validation dataset
print('Validation Dataset')
print('-'*50)
YOLOv5s_metrics_val = evaluate_model_mAP(model_s, validation_df, NUM_CLASSES, IMAGES_DIR)

# test dataset
print('Test Dataset')
print('-'*50)
YOLOv5s_metrics_test = evaluate_model_mAP(model_s, test_df, NUM_CLASSES, IMAGES_DIR)
# Out:
# YOLOv5s Evaluation
# --------------------------------------------------
# Validation Dataset
# --------------------------------------------------
# Starting detection on images...
# 0.0% of images processed
# 25.0% of images processed
# 50.0% of images processed
# 75.0% of images processed
# 100% of images processed
# Finished image processing
# Starting mAP evaluation...
# Evaluation finished
# Evaluation time = 57.48 seconds
# --------------------------------------------------
# Mean Average Precision
# mAP@0.5:0.05:0.95 = 63.43
# mAp@.50 = 93.31
# mAp@.75 = 73.81
# --------------------------------------------------
# Test Dataset
# --------------------------------------------------
# Starting detection on images...
# 0.0% of images processed
# 24.96714848883049% of images processed
# 49.93429697766098% of images processed
# 74.90144546649145% of images processed
# 99.86859395532196% of images processed
# 100% of images processed
# Finished image processing
# Starting mAP evaluation...
# Evaluation finished
# Evaluation time = 50.25 seconds
# --------------------------------------------------
# Mean Average Precision
# mAP@0.5:0.05:0.95 = 59.93
# mAp@.50 = 88.62
# mAp@.75 = 71.29
# --------------------------------------------------

# %% [markdown]
# ### YOLOv5m medium size

# %%
# Evaluate YOLOv5m

# validation dataset
print('YOLOv5m Evaluation')
print('-'*50)

# validation dataset
print('Validation Dataset')
print('-'*50)
YOLOv5m_metrics_val = evaluate_model_mAP(model_m, validation_df, NUM_CLASSES, IMAGES_DIR)

# test dataset
print('Test Dataset')
print('-'*50)
YOLOv5m_metrics_test = evaluate_model_mAP(model_m, test_df, NUM_CLASSES, IMAGES_DIR)
# Out:
# YOLOv5m Evaluation
# --------------------------------------------------
# Validation Dataset
# --------------------------------------------------
# Starting detection on images...
# 0.0% of images processed
# 25.0% of images processed
# 50.0% of images processed
# 75.0% of images processed
# 100% of images processed
# Finished image processing
# Starting mAP evaluation...
# Evaluation finished
# Evaluation time = 60.72 seconds
# --------------------------------------------------
# Mean Average Precision
# mAP@0.5:0.05:0.95 = 64.72
# mAp@.50 = 93.45
# mAp@.75 = 75.06
# --------------------------------------------------
# Test Dataset
# --------------------------------------------------
# Starting detection on images...
# 0.0% of images processed
# 24.96714848883049% of images processed
# 49.93429697766098% of images processed
# 74.90144546649145% of images processed
# 99.86859395532196% of images processed
# 100% of images processed
# Finished image processing
# Starting mAP evaluation...
# Evaluation finished
# Evaluation time = 49.32 seconds
# --------------------------------------------------
# Mean Average Precision
# mAP@0.5:0.05:0.95 = 62.19
# mAp@.50 = 88.94
# mAp@.75 = 74.98
# --------------------------------------------------

# %% [markdown]
# ### YOLOv5l large size

# %%
# Evaluate YOLOv5l

# validation dataset
print('YOLOv5l Evaluation')
print('-'*50)

# validation dataset
print('Validation Dataset')
print('-'*50)
YOLOv5l_metrics_val = evaluate_model_mAP(model_l, validation_df, NUM_CLASSES, IMAGES_DIR)

# test dataset
print('Test Dataset')
print('-'*50)
YOLOv5l_metrics_test = evaluate_model_mAP(model_l, test_df, NUM_CLASSES, IMAGES_DIR)
# Out:
# YOLOv5l Evaluation
# --------------------------------------------------
# Validation Dataset
# --------------------------------------------------
# Starting detection on images...
# 0.0% of images processed
# 25.0% of images processed
# 50.0% of images processed
# 75.0% of images processed
# 100% of images processed
# Finished image processing
# Starting mAP evaluation...
# Evaluation finished
# Evaluation time = 77.55 seconds
# --------------------------------------------------
# Mean Average Precision
# mAP@0.5:0.05:0.95 = 64.27
# mAp@.50 = 93.66
# mAp@.75 = 74.15
# --------------------------------------------------
# Test Dataset
# --------------------------------------------------
# Starting detection on images...
# 0.0% of images processed
# 24.96714848883049% of images processed
# 49.93429697766098% of images processed
# 74.90144546649145% of images processed
# 99.86859395532196% of images processed
# 100% of images processed
# Finished image processing
# Starting mAP evaluation...
# Evaluation finished
# Evaluation time = 68.52 seconds
# --------------------------------------------------
# Mean Average Precision
# mAP@0.5:0.05:0.95 = 61.55
# mAp@.50 = 88.27
# mAp@.75 = 72.83
# --------------------------------------------------
